# %%
import pandas as pd
import numpy as np
import string

import openpyxl
from openpyxl.styles import Font
from openpyxl.utils.dataframe import dataframe_to_rows

from docx import Document
from docx.shared import RGBColor
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# %%
df = pd.read_excel(r"C:\Users\zah48132\GSK\BDSD Team Site - Monthly Newsletter\08 Sep 2023\Sep2023 - Asset Capability Updates and TSC.xlsx",sheet_name="Asset Updates")
df_pdfg = pd.read_excel(r"C:\Users\zah48132\GSK\BDSD Team Site - Monthly Newsletter\08 Sep 2023\Sep2023 - Asset Capability Updates and TSC.xlsx",sheet_name="PDFG Updates 2")
df["Asset"] = pd.Series(df["Asset"]).fillna(method='ffill')
df_pdfg["Project"] = pd.Series(df_pdfg["Project"]).fillna(method='ffill')
df.head()
# Out:
#          Asset       Department  \
# 0  Dostarlimab         Upstream
# 1  Dostarlimab       Downstream
# 2  Dostarlimab  Viral Clearance
# 3  Depemokimab         Upstream
# 4  Depemokimab       Downstream
#
#   Current status (clinical trials, process development)  \
# 0  See here for a summary of the colorectal cance...
# 1  Support of B40 readiness for CTM2 (thaw mid-Se...
# 2                                        No updates
# 3  Supporting RTQs, PC report update and publicat...
# 4  Supporting RTQs, PC report update and publicat...
#
#                                      Ongoing studies  \
# 0  MR23-060 will investigate both the impacts of ...
# 1
# 2                                                NaN
# 3                                                NaN
# 4  IPH Strategy: endorsed by CMC team; need furth...
#
#                              Monthly Accomplishments  \
# 0  The Dostarlimab team recently completed a stab...
# 1  Completion of CTM1 in B40; completion of the f...
# 2                                                NaN
# 3                                                NaN
# 4                  SSMQ report updated and published
#
#                               Ongoing Challenges
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4  \t BLA kickoff is planned for early September

# %% [markdown]
# # Asset Updates Code

# %%
def dataframe_to_excel(df):
    wb = openpyxl.Workbook()
    ws = wb.active

    for r in dataframe_to_rows(df, index=True, header=True):
        ws.append(r)

    return wb

def excel_to_word(excel_file, word_file):
    # Open the Excel workbook
    workbook = openpyxl.load_workbook(excel_file)
    sheet = workbook.active

    # Create a new Word document
    doc = Document()

    # Get the dimensions of the Excel table
    num_rows = sheet.max_row
    num_cols = sheet.max_column

# %%
worksheet = dataframe_to_excel(df)

# Open the Excel workbook
sheet = worksheet.active

# Create a new Word document
doc = Document()

# Get the dimensions of the Excel table
num_rows = sheet.max_row
num_cols = sheet.max_column

len(df["Asset"].unique())

# Create a Word table with the same dimensions as the Excel table
table = doc.add_table(rows=num_rows, cols=2)
table.style = 'Table Grid'
table.allow_autofit = False

yellow = openpyxl.styles.colors.Color(rgb='FFFF00')

# Loop through each cell in the Excel table and copy its value and format to the Word table
table_row = 3
for count, row in enumerate(sheet.iter_rows(min_row=3, max_row=num_rows-1, min_col=1, max_col=num_cols)):
    
    paragraph_asset = table.cell(row_idx=count+3, col_idx=0).add_paragraph()
    run_asset = paragraph_asset.add_run(str(sheet.cell(row=table_row, column=2).value))

    # Apply font styling to the run
    font = run_asset.font
    font.name = 'Arial Narrow'
    # Set the font size (e.g., 12pt)
    font.size = Pt(12)
    # Set the font color (e.g., red)
    font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
    # Apply bold and italic styles
    font.bold = True
    font.italic = False
    font.underline = False
    
    paragraph_asset.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

    paragraph = table.cell(row_idx=count+3, col_idx=1).add_paragraph()

    # Add text to the paragraph
    run_head1 = paragraph.add_run(str(sheet.cell(row=1, column=4).value))
    paragraph.add_run("\n")
    run_up1 = paragraph.add_run("Upstream: ")
    run_text1 = paragraph.add_run(str(sheet.cell(table_row,4).value))
    paragraph.add_run("\n")

    run_down1 = paragraph.add_run("Downstream: ")
    run_text2 = paragraph.add_run(str(sheet.cell(table_row+1,4).value))
    paragraph.add_run("\n")
    
    run_vc1 = paragraph.add_run("Viral Clearance: ")
    run_text3 = paragraph.add_run(str(sheet.cell(table_row+2,4).value))
    paragraph.add_run("\n")


    run_head2 = paragraph.add_run(str(sheet.cell(row=1, column=5).value))
    paragraph.add_run("\n")
    run_up2 = paragraph.add_run("Upstream: ")
    run_text4 = paragraph.add_run(str(sheet.cell(table_row,5).value))
    paragraph.add_run("\n")

    run_down2 = paragraph.add_run("Downstream: ")
    run_text5 = paragraph.add_run(str(sheet.cell(table_row+1,5).value))
    paragraph.add_run("\n")
    
    run_vc2 = paragraph.add_run("Viral Clearance: ")
    run_text6 = paragraph.add_run(str(sheet.cell(table_row+2,5).value))
    paragraph.add_run("\n")


    run_head3 = paragraph.add_run(str(sheet.cell(row=1, column=6).value))
    paragraph.add_run("\n")
    run_up3 = paragraph.add_run("Upstream: ")
    run_text7 = paragraph.add_run(str(sheet.cell(table_row,6).value))
    paragraph.add_run("\n")

    run_down3 = paragraph.add_run("Downstream: ")
    run_text8 = paragraph.add_run(str(sheet.cell(table_row+1,6).value))
    paragraph.add_run("\n")
    
    run_vc3 = paragraph.add_run("Viral Clearance: ")
    run_text9 = paragraph.add_run(str(sheet.cell(table_row+2,6).value))
    paragraph.add_run("\n")


    run_head4 = paragraph.add_run(str(sheet.cell(row=1, column=7).value))
    paragraph.add_run("\n")
    run_up4 = paragraph.add_run("Upstream: ")
    run_text10 = paragraph.add_run(str(sheet.cell(table_row,7).value))
    paragraph.add_run("\n")

    run_down4 = paragraph.add_run("Downstream: ")
    run_text11 = paragraph.add_run(str(sheet.cell(table_row+1,7).value))
    paragraph.add_run("\n")
    
    run_vc4 = paragraph.add_run("Viral Clearance: ")
    run_text12 = paragraph.add_run(str(sheet.cell(table_row+2,7).value))
    paragraph.add_run("\n")

    table_row += 3

    run_heads = [run_head1,run_head2,run_head3,run_head4]
    run_up = [run_up1,run_up2,run_up3,run_up4]
    run_down = [run_down1,run_down2,run_down3,run_down4]
    run_vc = [run_vc1,run_vc2,run_vc3,run_vc4]
    run_text = [run_text1,run_text2,run_text3,run_text4,run_text5,run_text6,run_text7,run_text8,run_text9,run_text10,run_text11,run_text12]


    for i in run_heads:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(12)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = False
        font.underline = True
    
    for i in run_up:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(255, 102, 0)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = True

    for i in run_down:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(3, 37, 126)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = True
    
    for i in run_vc:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(128, 0, 128)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = True
    
    for i in run_text:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
        
doc.save(r"M:\Zach Hatzenbeller\newsletter_scripts\Sept2023_Asset_Updates.docx")

# %%
for i in df_pdfg["Project"].iloc[:-1]:
    print(i.splitlines())
# Out:
# ['Core Team', '(Leads: Carolyn Scott, Kathryn Meintel)']
# ['Media and Feed', '(Leads: Jan Fernandez, Greeshma Manomohan)']
# ['Media and Feed Development*', '(Lead: Keegan Orzechowski)']
# ['Cell line development', '(Lead: Xiaodan Ji)']
# ['ATF (N-1)', '(Leads: Jon Wu, Adam Mobley)']
# ['Process Characterization ', '(Lead: Carolyn Scott)']
# ['Harvest ', '(Lead: Stijn Koshari, Sam Heidlebaugh)']
# ['Affinity Chromatography ', '(Lead: Erica Hui)']
# ['Viral Inactivation ', '(Leads: Jen Fetter, Hope McMahon)']
# ['Anion Exchange Chromatography ', '(Leads: Hamish Bettany, Bill Dowd)']
# ['3rd Chrom Step ', '(Leads: Chris Gerberich, David Hilton)']
# ['Virus Filtration ', '(Leads: Hong Zhang, Krystal Brostek)']
# ['UFDF/FF', '(Leads: Sam H, Lekha Revur)']
# ['BDS Freeze/Thaw ', '(Leads: Yanhong Feng, Becky Greiner)']
# ['In-Process Hold', '(Leads: Maggie Pong, Christiane Mushagasha)']
# ['Analytical Strategy ', '(Lead: Kelsey Morgan)']
# ['PAT ', '(Leads: Yu Luo, Michael Janderchick, Kelsey Morgan)']
# ['PAT ', '(Leads: Yu Luo, Michael Janderchick, Kelsey Morgan)']
# ['PAT ', '(Leads: Yu Luo, Michael Janderchick, Kelsey Morgan)']
# ['Demo (Scale-Up) ', '(Lead: Alex Kelly)']
# ['Bioreactor Scalability ', '(Lead: Jon Raley)']
# ['Advanced Data Analytics* ', '(Lead: Sameer Talwar)']
# ['Externalization*', '(Dave Stevenson)']

# %%
worksheet = dataframe_to_excel(df_pdfg)

project_list = [i.splitlines()[0] for i in df_pdfg["Project"].iloc[:-1]]
lead_list = [i.splitlines()[1] for i in df_pdfg["Project"].iloc[:-1]]

# Open the Excel workbook
sheet = worksheet.active

# Create a new Word document
doc = Document()

# Get the dimensions of the Excel table
num_rows = sheet.max_row
num_cols = sheet.max_column

len(df_pdfg["Project"].unique())

# Create a Word table with the same dimensions as the Excel table
table = doc.add_table(rows=num_rows, cols=2)
table.style = 'Table Grid'
table.allow_autofit = False

yellow = openpyxl.styles.colors.Color(rgb='FFFF00')

# Loop through each cell in the Excel table and copy its value and format to the Word table
table_row = 3
for count, row in enumerate(sheet.iter_rows(min_row=3, max_row=num_rows-1, min_col=1, max_col=num_cols)):
    
    paragraph_asset = table.cell(row_idx=count+3, col_idx=0).add_paragraph()
    run_project = paragraph_asset.add_run(project_list[count])
    paragraph_asset.add_run("\n")
    run_leads = paragraph_asset.add_run(lead_list[count])

    # Apply font styling to the run
    font = run_project.font
    font.name = 'Arial Narrow'
    # Set the font size (e.g., 12pt)
    font.size = Pt(12)
    # Set the font color (e.g., red)
    font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
    # Apply bold and italic styles
    font.bold = True
    font.italic = False
    font.underline = False

    # Apply font styling to the run
    font = run_leads.font
    font.name = 'Arial Narrow'
    # Set the font size (e.g., 12pt)
    font.size = Pt(11)
    # Set the font color (e.g., red)
    font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
    # Apply bold and italic styles
    font.bold = False
    font.italic = False
    font.underline = False
    
    paragraph_asset.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

    paragraph = table.cell(row_idx=count+3, col_idx=1).add_paragraph()

    # Add text to the paragraph
    run_head1 = paragraph.add_run(str(sheet.cell(row=1, column=3).value))
    paragraph.add_run("\n")
    if str(sheet.cell(table_row,3).value) == "nan":
        run_text1 = paragraph.add_run("No Update")
        paragraph.add_run("\n")
    else:
        run_text1 = paragraph.add_run(str(sheet.cell(table_row,3).value))
        paragraph.add_run("\n")

    run_head2 = paragraph.add_run(str(sheet.cell(row=1, column=4).value))
    paragraph.add_run("\n")
    if str(sheet.cell(table_row,4).value) == "nan":
        run_text2 = paragraph.add_run("No Update")
        paragraph.add_run("\n")
    else:
        run_text2 = paragraph.add_run(str(sheet.cell(table_row,4).value))
        paragraph.add_run("\n")

    run_head3 = paragraph.add_run(str(sheet.cell(row=1, column=5).value))
    paragraph.add_run("\n")
    if str(sheet.cell(table_row,5).value) == "nan":
        run_text3 = paragraph.add_run("No Update")
        paragraph.add_run("\n")
    else:
        run_text3 = paragraph.add_run(str(sheet.cell(table_row,5).value))
        paragraph.add_run("\n")

    run_head4 = paragraph.add_run(str(sheet.cell(row=1, column=6).value))
    paragraph.add_run("\n")
    if str(sheet.cell(table_row,6).value) == "nan":
        run_text4 = paragraph.add_run("No Update")
        paragraph.add_run("\n")
    else:
        run_text4 = paragraph.add_run(str(sheet.cell(table_row,6).value))
        paragraph.add_run("\n")

    table_row += 1

    run_heads = [run_head1,run_head2,run_head3,run_head4]
    run_up = [run_up1,run_up2,run_up3,run_up4]
    run_text = [run_text1,run_text2,run_text3,run_text4]


    for i in run_heads:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(12)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = False
        font.underline = True
    
    for i in run_up:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(255, 102, 0)  # RGBColor(red, green, blue)
        # Apply bold and italic styles
        font.bold = True
        font.italic = True
    
    for i in run_text:
        # Apply font styling to the run
        font = i.font
        font.name = 'Arial Narrow'
        # Set the font size (e.g., 12pt)
        font.size = Pt(10)
        # Set the font color (e.g., red)
        font.color.rgb = RGBColor(0, 0, 0)  # RGBColor(red, green, blue)

doc.save(r"M:\Zach Hatzenbeller\newsletter_scripts\Sept2023_PDFG_Updates.docx")
